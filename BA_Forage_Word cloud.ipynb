# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/00/09/abb305dce85911b8fba382926cfc57f2f257729e25937fdcc63f3a1a67f9/wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\shondita\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\shondita\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\shondita\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shondita\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shondita\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl (299 kB)
#    ---------------------------------------- 0.0/299.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/299.9 kB ? eta -:--:--
#    -------- ------------------------------- 61.4/299.9 kB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 112.6/299.9 kB 1.7 MB/s eta 0:00:01
#    --------------------- ------------------ 163.8/299.9 kB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 163.8/299.9 kB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 163.8/299.9 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- ------ 245.8/299.9 kB 942.1 kB/s eta 0:00:01
#    -------------------------------------- 299.9/299.9 kB 975.4 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
file_path = "D://My Folder//Forage//British Airways//BA_cleaned_reviews.csv"  
df = pd.read_csv(file_path)

# %%
all_reviews = ' '.join(df['cleaned_reviews'].dropna())

# %%
wordcloud = WordCloud(
    width=800, 
    height=400, 
    background_color='white', 
    colormap='viridis', 
    max_words=200
).generate(all_reviews)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.title('Word Cloud of Customer Reviews', fontsize=16)
plt.show()
